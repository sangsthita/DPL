# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA Available: True
# GPU Name: Tesla T4

# %%
# Clone the YOLOv7 GitHub repository
# !git clone https://github.com/WongKinYiu/yolov7.git
# %cd yolov7

# Install dependencies
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'yolov7' already exists and is not an empty directory.
# /content/yolov7
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content/yolov7

# %%
import os
os.chdir('/content/yolov7')

# %%
# !pwd
# Out:
# /content/yolov7

# %%
# !python split_dataset.py --folder /content/yolov7/face_mask --train 80 --validation 10 --test 10 --dest face_mask_dataset

# %%
# !python train.py --workers 8 --batch-size 16 --device 0 --data /content/yolov7/face_mask_gpu.yaml --img 640 640 --cfg /content/yolov7/cfg/training/yolov7-face_mask.yaml --weights yolov7_training.pt --name yolov7-face-mask --hyp data/hyp.scratch.custom.yaml --epochs 10
# Out:
# 2025-02-11 09:46:29.826707: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739267189.847281   32739 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739267189.854152   32739 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-11 09:46:29.875177: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python detect.py --weights /content/yolov7/runs/train/yolov7-face-mask5/weights/best.pt --source /content/yolov7/inference/images/face-mask.png
# Out:
# Namespace(weights=['/content/yolov7/runs/train/yolov7-face-mask5/weights/best.pt'], source='/content/yolov7/inference/images/face-mask.png', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.5.1+cu124 CUDA:0 (Tesla T4, 15095.0625MB)
#
# ...
